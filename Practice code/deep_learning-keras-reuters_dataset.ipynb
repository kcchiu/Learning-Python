# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.optimizers import SGD
from keras.datasets import reuters
from keras.preprocessing.text import Tokenizer
import numpy as np
import keras

max_words = 1000
batch_size = 32

(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=max_words,
                                                         test_split=0.2)
# Out:
# Using TensorFlow backend.

# %%
tokenizer = Tokenizer(num_words=max_words)
x_train = tokenizer.sequences_to_matrix(x_train, mode='binary')
x_test = tokenizer.sequences_to_matrix(x_test, mode='binary')

# %%
num_classes = np.max(y_train) + 1
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(max_words,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(x_train, y_train,
          epochs=5,
          batch_size=batch_size,
          verbose=1,
          validation_split=0.1)
# Out:
# Train on 8083 samples, validate on 899 samples
# Epoch 1/5
# 8083/8083 [==============================] - 4s - loss: 1.4292 - acc: 0.6785 - val_loss: 1.0891 - val_acc: 0.7664
# Epoch 2/5
#  - ETA: 3s - loss: 0.8720 - acc: 0.7937
# Epoch 3/5
# 8083/8083 [==============================] - 4s - loss: 0.5505 - acc: 0.8651 - val_loss: 0.8892 - val_acc: 0.8020
# Epoch 4/5
# 8083/8083 [==============================] - 4s - loss: 0.4157 - acc: 0.9003 - val_loss: 0.8804 - val_acc: 0.8098
# Epoch 5/5
# 8083/8083 [==============================] - 5s - loss: 0.3236 - acc: 0.9165 - val_loss: 0.9161 - val_acc: 0.7998

# %%
score = model.evaluate(x_test, y_test,
                       batch_size=batch_size, verbose=1)
# Out:
# 2246/2246 [==============================] - 0s

# %%
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.88858802533
# Test accuracy: 0.792965271594
